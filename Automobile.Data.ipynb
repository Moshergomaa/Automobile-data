# %%
import pandas as pd
df = pd.read_csv("automobile_data.csv")
from numpy import NaN
from scipy.stats import iqr
import numpy as np
import scipy
# %matplotlib inline

df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
df.shape
# Out:
# (205, 26)

# %%
df.loc[3]
# Out:
# symboling                2
# normalized-losses      164
# make                  audi
# fuel-type              gas
# aspiration             std
# num-of-doors          four
# body-style           sedan
# drive-wheels           fwd
# engine-location      front
# wheel-base            99.8
# length               176.6
# width                 66.2
# height                54.3
# curb-weight           2337
# engine-type            ohc
# num-of-cylinders      four
# engine-size            109
# fuel-system           mpfi
# bore                  3.19
# stroke                 3.4
# compression-ratio       10
# horsepower             102
# peak-rpm              5500
# city-mpg                24
# highway-mpg             30
# price                13950
# Name: 3, dtype: object

# %%
df.replace('?', NaN, inplace=True) 
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3               NaN  alfa-romero       gas        std
# 1            3               NaN  alfa-romero       gas        std
# 2            1               NaN  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
df.head(11)
# Out:
#     symboling normalized-losses         make fuel-type aspiration  \
# 0           3               NaN  alfa-romero       gas        std
# 1           3               NaN  alfa-romero       gas        std
# 2           1               NaN  alfa-romero       gas        std
# 3           2               164         audi       gas        std
# 4           2               164         audi       gas        std
# 5           2               NaN         audi       gas        std
# 6           1               158         audi       gas        std
# 7           1               NaN         audi       gas        std
# 8           1               158         audi       gas      turbo
# 9           0               NaN         audi       gas      turbo
# 10          2               192          bmw       gas        std
#
#    num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0           two  convertible          rwd           front        88.6  ...
# ...

# %%
df['symboling'].dtypes , df['normalized-losses'].dtypes
# Out:
# (dtype('int64'), dtype('O'))

# %%
df['symboling'] = df['symboling'].astype(float) 
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0          3.0               NaN  alfa-romero       gas        std
# 1          3.0               NaN  alfa-romero       gas        std
# 2          1.0               NaN  alfa-romero       gas        std
# 3          2.0               164         audi       gas        std
# 4          2.0               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200       -1.0                95        volvo       gas        std
# 201       -1.0                95        volvo       gas      turbo
# 202       -1.0                95        volvo       gas        std
# 203       -1.0                95        volvo    diesel      turbo
# 204       -1.0                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
(df['symboling'].isnull().sum() * 100/ len('symboling'))
# Out:
# 0.0

# %%
df.replace(NaN, df.median(), inplace=True) 
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0        3.0               115  alfa-romero       gas        std          two
# 1        3.0               115  alfa-romero       gas        std          two
# 2        1.0               115  alfa-romero       gas        std          two
# 3        2.0               164         audi       gas        std         four
# 4        2.0               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
df.make.unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'mazda', 'mercedes-benz', 'mercury',
#        'mitsubishi', 'nissan', 'peugot', 'plymouth', 'porsche', 'renault',
#        'saab', 'subaru', 'toyota', 'volkswagen', 'volvo'], dtype=object)

# %%
df.make.nunique()
# Out:
# 22

# %%
df['price'] = df['price'].astype(float)
df['price'].mean()
# Out:
# 13150.307317073171

# %%
df['horsepower'] = df['horsepower'].astype(int)
filt = (df['horsepower'] >100)

# %%
df.loc[filt]
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0          3.0               115  alfa-romero       gas        std
# 1          3.0               115  alfa-romero       gas        std
# 2          1.0               115  alfa-romero       gas        std
# 3          2.0               164         audi       gas        std
# 4          2.0               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200       -1.0                95        volvo       gas        std
# 201       -1.0                95        volvo       gas      turbo
# 202       -1.0                95        volvo       gas        std
# 203       -1.0                95        volvo    diesel      turbo
# 204       -1.0                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
def get_percentile(df, percentile_rank):
    df = df.sort_values(by='price').reset_index()
    index = (len(df.index)-1) * percentile_rank / 100.0
    index = int(index)
    return df.at[index, 'price']

# %%
get_percentile(df, 25)
# Out:
# 7788.0

# %%
get_percentile(df, 75)
# Out:
# 16500.0

# %%
def interquartile_range(df):
    
    p75 = get_percentile(df, 75) 
    p25 = get_percentile(df, 25) 
    iqr = p75 - p25  
    return iqr

# %%
interquartile_range(df)
# Out:
# 8712.0

# %%
df['height'].plot()
# Out:
# <AxesSubplot:>

# %%
df['drive-wheels'].value_counts()
# Out:
# fwd    120
# rwd     76
# 4wd      9
# Name: drive-wheels, dtype: int64

# %%
df2 = pd.DataFrame({'drive-wheels':['rwd', 'fwd', '4wd'], 'val':[120, 76, 9]})
ax = df.plot.bar(x='drive-wheels', y='val', rot=0)

# %%
df.plot(x='height', y='price', style='o')
# Out:
# <AxesSubplot:xlabel='height'>
